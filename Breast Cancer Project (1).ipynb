# %%
# Aim:-chek Melignant tumor or Benign tumor based on dataset of patient.

# cancerous means:-appearing abnormal behaviour in our cells.

# There are two types Tumor:
"""1.Benign Tumor                  2.Melignant Tumor
    -Non cancerous                 -Cancerous
    -Capsulated                     -Non Capsulated
    -slow growing                   -Fast growing
    -Cells are normal               -Cells have large size,dark nuclei
                                     may have abnormal shape"""
#Data collection procedure
"""Fine needle aspiration is  a type of biopsy procedure.In this procdure ,a thin needle is inserted
in area of abnormal tissue or body fluid."""
# Out:
# 'Fine needle aspiration is  a type of biopsy procedure.In this procdure ,a thin needle is inserted\nin area of abnormal tissue or body fluid.'

# %%
#import all relevant Library
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
#load the datasets
os.chdir('C:\\Users\\Asus\\Downloads')

# %%
data=pd.read_csv('Breast.csv')
display(data)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M      17.2776        0.3001          0.1471     0.2419
# 1      842517         M      20.5700       17.7700        132.9000  1326.0000
# 2    84300903         M      19.6900       21.2500        130.0000  1203.0000
# 3    84348301         M      11.4200       20.3800         77.5800   386.1000
# 4    84358402         M      20.2900       14.3400        135.1000  1297.0000
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M      21.5600       22.3900        142.0000  1479.0000
# 565    926682         M      20.1300       28.2500        131.2000  1261.0000
# 566    926954         M      16.6000       28.0800        108.3000   858.1000
# 567    927241         M      20.6000       29.3300        140.1000  1265.0000
# 568     92751         B       7.7600       24.5400         47.9200   181.0000
#
# ...

# %%
x=data.drop(columns=['id','diagnosis'],axis=1)
display(x)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.2776        0.3001          0.1471     0.2419          0.07871
# 1        20.5700       17.7700        132.9000  1326.0000          0.08474
# 2        19.6900       21.2500        130.0000  1203.0000          0.10960
# 3        11.4200       20.3800         77.5800   386.1000          0.14250
# 4        20.2900       14.3400        135.1000  1297.0000          0.10030
# ..           ...           ...             ...        ...              ...
# 564      21.5600       22.3900        142.0000  1479.0000          0.11100
# 565      20.1300       28.2500        131.2000  1261.0000          0.09780
# 566      16.6000       28.0800        108.3000   858.1000          0.08455
# 567      20.6000       29.3300        140.1000  1265.0000          0.11780
# 568       7.7600       24.5400         47.9200   181.0000          0.05263
#
# ...

# %%
y=data['diagnosis']
display(y)
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
y.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#check any missing value in data
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
#above 1-> Malignant tumor,0->Benign tumor
#spilit data into train test
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=2)
print(x.shape)
print(y.shape)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (569, 30)
# (569,)
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %%
#change data type for LebelEncoding
y=y.astype('category')
print(y.dtypes)
# Out:
# category

# %%
y=y.cat.codes
print(y.head())
print(y.tail())
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int8
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# dtype: int8

# %%
#create logistic Regression Model
model=LogisticRegression()
model.fit(x_train,y_train)
print(model)
# Out:
# LogisticRegression()

# %%
#print model accuracy on train datasets
Y_train_pred=model.predict(x_train)
print(accuracy_score(y_train,Y_train_pred))
# Out:
# 0.9560439560439561

# %%
#print  accuracy for test datasets
Y_test_pred=model.predict(x_test)
print(accuracy_score(y_test,Y_test_pred))
# Out:
# 0.9298245614035088

# %%
input=np.array([20.57,17.77,132.9,1326,0.08474,0.07864,0.0869,0.07017,0.1812,0.05667,0.5435,0.7339,3.398,74.08,0.005225,0.01308,0.0186,0.0134,0.01389,0.003532,24.99,23.41,158.8,1956,0.1238,0.1866,0.2416,0.186,0.275,0.08902])
print(np.shape(input))
# Out:
# (30,)

# %%
#predict cancer of given input dataset
input_data_reshaped=np.reshape(input,(1,30))
prediction=model.predict(input_data_reshaped)
print(prediction)
if(prediction[0]==1):
    print('Malignant Tumor is cancer')
else:
    print('Benign Tumor is not cancer')
# Out:
# ['M']
# Benign Tumor is not cancer

# %%
# take other input dataset
input1=np.array([12.04,28.14,76.85,449.9,0.08752,0.06,0.02367,0.02377,0.1854,0.05698,0.6061,2.643,4.099,44.96,0.007517,0.01555,0.01465,0.01183,0.02047,0.003883,13.6,33.33,87.24,567.6,0.1041,0.09726,0.05524,0.05547,0.2404,0.06639])
input1_data_reshaped=np.reshape(input1,(1,30))
prediction=model.predict(input1_data_reshaped)
print(prediction)
if(prediction[0]==1):
    print('Malignant Tumor is cancer')
else:
    print('Benign Tumor is not cancer')
# Out:
# ['B']
# Benign Tumor is not cancer

# %%
'''conclusion:-we have created Logistic Regression model for loaded cancer prediction datasets. 
   I have seen accuracy=0.9298245614035088 based on test datasets.'''
# Out:
# 'conclusion:-we have created Logistic Regression model for loaded cancer prediction datasets. \n   I have seen accuracy=0.9298245614035088 based on test datasets.'
